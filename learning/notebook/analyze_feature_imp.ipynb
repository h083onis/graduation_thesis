# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../resource/feature_importance2.csv', index_col=0, header=0)
df
# Out:
#                                   la            ld            nf           nd  \
# openstack-lgb-random-0  36986.011408    416.048702   2346.763311  1102.995291
# openstack-lgb-random-1  36312.797316    494.898806   2322.593277  1083.134401
# openstack-lgb-random-2  36948.658821    615.411507   1856.471376  1389.714090
# openstack-lgb-random-3  36011.124455    684.142803   1044.690405  2793.194202
# openstack-lgb-random-4  34573.204573    302.458000   1925.502823   976.659191
# qt-lgb-random-0         70849.803150   8760.449923  11895.633368  1443.207638
# qt-lgb-random-1         65227.592608   7102.086430  10325.400518  2106.923695
# qt-lgb-random-2         70559.048914   7503.807219  10701.551585  1679.262343
# qt-lgb-random-3         71558.179353  10365.273433  14053.902687  2859.931713
# qt-lgb-random-4         78132.450440  11868.176461  12887.939209  2914.491598
#
#                                  ns           ent        revd         nrev  \
# ...

# %%
df['project'] = df.index.map(lambda x: x.split('-')[0])
df
# Out:
#                                   la            ld            nf           nd  \
# openstack-lgb-random-0  36986.011408    416.048702   2346.763311  1102.995291
# openstack-lgb-random-1  36312.797316    494.898806   2322.593277  1083.134401
# openstack-lgb-random-2  36948.658821    615.411507   1856.471376  1389.714090
# openstack-lgb-random-3  36011.124455    684.142803   1044.690405  2793.194202
# openstack-lgb-random-4  34573.204573    302.458000   1925.502823   976.659191
# qt-lgb-random-0         70849.803150   8760.449923  11895.633368  1443.207638
# qt-lgb-random-1         65227.592608   7102.086430  10325.400518  2106.923695
# qt-lgb-random-2         70559.048914   7503.807219  10701.551585  1679.262343
# qt-lgb-random-3         71558.179353  10365.273433  14053.902687  2859.931713
# qt-lgb-random-4         78132.450440  11868.176461  12887.939209  2914.491598
#
#                                  ns           ent        revd         nrev  \
# ...

# %%
df2 = df.groupby('project').mean()
df2
# Out:
#                      la           ld            nf           nd          ns  \
# project
# openstack  36166.359315   502.591964   1899.204239  1469.139435  2102.82332
# qt         71265.414893  9119.958693  11972.885473  2200.763397  3135.84811
#
#                     ent        revd         nrev         rtime          hcmt  \
# project
# openstack   5895.680235    0.000000  1816.660898   4802.604262   4325.025150
# qt         14050.852445  116.198363  8192.529130  17731.679871  10171.430117
#
#            ...        rrexp         orexp         asexp         rsexp  \
# project    ...
# openstack  ...  1551.980837   2054.985202    193.857320    219.090779
# qt         ...  7931.271728  11634.228393  10449.678568  10909.651935
#
#                   osexp         asawr         rsawr         osawr  \
# project
# openstack    305.434522    193.837561   1452.925601   2601.032833
# qt         10207.388726  20790.320772  10598.546562  17762.001896
#
#                   churn          fix
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, axes = plt.subplots(2, 1,  figsize=(10, 8), tight_layout=True)

for i, row in enumerate(df2.iterrows()):
    axes[i].bar(df2.columns, row[1], label=row[0])
    
# プロットの表示
for i in range(2):
    axes[i].set_xlabel('columns')
    axes[i].set_ylabel('value')
    labels = axes[i].get_xticklabels()
    plt.setp(labels, rotation=45, fontsize=10)
axes[0].set_title("OpenStack feature importance") 
axes[1].set_title("Qt feature importance")

plt.show()
